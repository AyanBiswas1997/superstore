# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r"D:\Project superstore\notebooks\data\Train.csv")

# %%
data.shape
# Out:
# (8523, 12)

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
data.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
x=data.drop(columns=["Item_Outlet_Sales","Item_Identifier","Outlet_Identifier"])

# %%
y=data["Item_Outlet_Sales"]

# %%
x
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0           9.300          Low Fat         0.016047                  Dairy
# 1           5.920          Regular         0.019278            Soft Drinks
# 2          17.500          Low Fat         0.016760                   Meat
# 3          19.200          Regular         0.000000  Fruits and Vegetables
# 4           8.930          Low Fat         0.000000              Household
# ...           ...              ...              ...                    ...
# 8518        6.865          Low Fat         0.056783            Snack Foods
# 8519        8.380          Regular         0.046982           Baking Goods
# 8520       10.600          Low Fat         0.035186     Health and Hygiene
# 8521        7.210          Regular         0.145221            Snack Foods
# 8522       14.800          Low Fat         0.044878            Soft Drinks
#
# ...

# %%
y
# Out:
# 0       3735.1380
# 1        443.4228
# 2       2097.2700
# 3        732.3800
# 4        994.7052
#           ...
# 8518    2778.3834
# 8519     549.2850
# 8520    1193.1136
# 8521    1845.5976
# 8522     765.6700
# Name: Item_Outlet_Sales, Length: 8523, dtype: float64

# %%
categorical_columns=x.select_dtypes(include=["object"]).columns 
numerical_columns=x.select_dtypes(exclude=["object"]).columns

# %%
categorical_columns
# Out:
# Index(['Item_Fat_Content', 'Item_Type', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type'],
#       dtype='object')

# %%
numerical_columns
# Out:
# Index(['Item_Weight', 'Item_Visibility', 'Item_MRP',
#        'Outlet_Establishment_Year'],
#       dtype='object')

# %%
Item_Fat_Content_category=['Low Fat', 'Regular', 'low fat', 'LF', 'reg']
Item_Type_category=['Dairy', 'Soft Drinks', 'Meat', 'Fruits and Vegetables', 'Household',
       'Baking Goods', 'Snack Foods', 'Frozen Foods', 'Breakfast',
       'Health and Hygiene', 'Hard Drinks', 'Canned', 'Breads',
       'Starchy Foods', 'Others', 'Seafood']
Outlet_Size_category=['Medium', 'High', 'Small']
Outlet_Location_Type_category=['Tier 1', 'Tier 3', 'Tier 2']
Outlet_Type_category=['Supermarket Type1', 'Supermarket Type2', 'Grocery Store',
       'Supermarket Type3']

# %%
from sklearn.impute import SimpleImputer #handle missing values
from sklearn.preprocessing import OneHotEncoder #convert categorical to numerical
from sklearn.preprocessing import StandardScaler #scale the data
from sklearn.pipeline import Pipeline #pipeline
from sklearn.compose import ColumnTransformer #transform the columns
from sklearn.preprocessing import OrdinalEncoder #convert categorical to numerical

# %%
num_pipeline=Pipeline(
    steps=[

    ("imputer",SimpleImputer(strategy="most_frequent")),
    ("scaler",StandardScaler())
    ]

)

# %%
cat_pipeline=Pipeline(
    steps=[
        ("imputer",SimpleImputer(strategy="most_frequent")),
        ("ordinal",OrdinalEncoder(categories=[Item_Fat_Content_category,Item_Type_category,Outlet_Size_category,Outlet_Location_Type_category,Outlet_Type_category]))

    ])

# %%
preprocessor=ColumnTransformer(
    [
        
        ('num_pipeline',num_pipeline,numerical_columns),
        ('cat_pipeline',cat_pipeline,categorical_columns)
    ]
)

# %%
num_pipeline
# Out:
# Pipeline(steps=[('imputer', SimpleImputer(strategy='most_frequent')),
#                 ('scaler', StandardScaler())])

# %%
cat_pipeline
# Out:
# Pipeline(steps=[('imputer', SimpleImputer(strategy='most_frequent')),
#                 ('ordinal',
#                  OrdinalEncoder(categories=[['Low Fat', 'Regular', 'low fat',
#                                              'LF', 'reg'],
#                                             ['Dairy', 'Soft Drinks', 'Meat',
#                                              'Fruits and Vegetables',
#                                              'Household', 'Baking Goods',
#                                              'Snack Foods', 'Frozen Foods',
#                                              'Breakfast', 'Health and Hygiene',
#                                              'Hard Drinks', 'Canned', 'Breads',
#                                              'Starchy Foods', 'Others',
#                                              'Seafood'],
#                                             ['Medium', 'High', 'Small'],
#                                             ['Tier 1', 'Tier 3', 'Tier 2'],
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=30)

# %%
X_train
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility      Item_Type  Item_MRP  \
# 2959          NaN               LF         0.039452    Snack Foods   39.5480
# 3336        7.435          Low Fat         0.205605  Starchy Foods  207.7638
# 5245        7.930          Low Fat         0.005557   Frozen Foods  122.1414
# 4992       20.250          Low Fat         0.014281      Household  148.0418
# 5295          NaN          Low Fat         0.020388      Household   44.4112
# ...           ...              ...              ...            ...       ...
# 4859       13.500          Regular         0.000000    Snack Foods   78.3960
# 919         7.445          Low Fat         0.037691   Baking Goods   73.3354
# 500        12.150          Low Fat         0.000000      Household  117.8150
# 4517          NaN          Regular         0.019228    Snack Foods  163.9842
# 5925        7.785          Low Fat         0.139553          Dairy  105.6306
#
# ...

# %%
X_test
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 817           NaN          Regular         0.150342                   Meat
# 7534          NaN          Low Fat         0.034203           Baking Goods
# 6686        7.365          Low Fat         0.160217            Snack Foods
# 1856       11.150          Regular         0.105737           Baking Goods
# 5393       21.250          Low Fat         0.010019                   Meat
# ...           ...              ...              ...                    ...
# 6536       18.000          Regular         0.238832  Fruits and Vegetables
# 2811       15.000          Low Fat         0.064272            Hard Drinks
# 6182       18.000          Low Fat         0.019383     Health and Hygiene
# 5007        8.655          Regular         0.088178            Snack Foods
# 7917       12.500          Regular         0.109901  Fruits and Vegetables
#
# ...

# %%
x_scaled_train=preprocessor.fit_transform(X_train)

# %%
x_scaled_test=preprocessor.transform(X_test)

# %%
preprocessor.get_feature_names_out()
# Out:
# array(['num_pipeline__Item_Weight', 'num_pipeline__Item_Visibility',
#        'num_pipeline__Item_MRP',
#        'num_pipeline__Outlet_Establishment_Year',
#        'cat_pipeline__Item_Fat_Content', 'cat_pipeline__Item_Type',
#        'cat_pipeline__Outlet_Size', 'cat_pipeline__Outlet_Location_Type',
#        'cat_pipeline__Outlet_Type'], dtype=object)

# %%
X_train=pd.DataFrame(x_scaled_train,columns=preprocessor.get_feature_names_out())
X_test=pd.DataFrame(x_scaled_test,columns=preprocessor.get_feature_names_out())

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso,ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score,accuracy_score

# %%
import numpy as np
def evaluate_model(true,predicted):
    mse=mean_squared_error(true,predicted)
    mae=mean_absolute_error(true,predicted)
    rmse=np.sqrt(mean_squared_error(true,predicted))
    r2_scuare=r2_score(true,predicted)
    return mae,r2_square,rmse

# %%
models={
    "LinearRegression":LinearRegression(),
    "Ridge":Ridge(),
    "Lasso":Lasso(),
    "ElasticNet":ElasticNet(),
    "svm":SVR(),
    "DecisionTree":DecisionTreeRegressor(),
    "RandomForest":RandomForestRegressor()
    }

# %%
list(models)
# Out:
# ['LinearRegression',
#  'Ridge',
#  'Lasso',
#  'ElasticNet',
#  'svm',
#  'DecisionTree',
#  'RandomForest']

# %%
list(models.values())
# Out:
# [LinearRegression(),
#  Ridge(),
#  Lasso(),
#  ElasticNet(),
#  SVR(),
#  DecisionTreeRegressor(),
#  RandomForestRegressor()]

# %%
train_model_list=[]
model_list=[]
r2_score_list=[]

# %%
for i in range(len(list(models))):
    model=list(models.values())[i]
    print(model)
# Out:
# LinearRegression()
# Ridge()
# Lasso()
# ElasticNet()
# SVR()
# DecisionTreeRegressor()
# RandomForestRegressor()

# %%
for i in range(len(list(models))):
    model=list(models.values())[i]
    model.fit(X_train,y_train)

    #Make Predictions
    y_pred=model.predict(X_test)

    #this is a validation(test) score
    mae, rmse, r2_square=evaluate_model(y_test,y_pred)

    print(list(models.keys())[i])
    model_list.append(list(models.keys())[i])

    print('Model Training Performance')
    print("RMSE:",rmse)
    print("MAE:",mae)
    print("R2 score",r2_square*100)


    r2_score_list.append(r2_square)
    
    print('='*35)
    print('\n')
# Out:
# LinearRegression
# Model Training Performance
# RMSE: 1157.1404835619858
# MAE: 1029.5689501724096
# R2 score 138150.5620564543
# ...
#
#
# Ridge
# Model Training Performance
# RMSE: 1381.505620564543
# MAE: 1029.5536845321449
# R2 score 138150.47577426428
# ...
#
#
# Lasso
# Model Training Performance
# RMSE: 1381.5047577426428
# MAE: 1029.2959053078112
# R2 score 138149.96706211765
# ...
#
#
# ElasticNet
# Model Training Performance
# RMSE: 1381.4996706211764
# MAE: 1068.3968316025246
# R2 score 143012.8706730063
# ...
#
#
# svm
# Model Training Performance
# RMSE: 1430.1287067300632
# MAE: 1294.273864085458
# R2 score 174318.46777026792
# ...
#
#
# DecisionTree
# Model Training Performance
# RMSE: 1743.1846777026792
# MAE: 1080.123668596011
# R2 score 156211.02522143614
# ...
#
#
# RandomForest
# Model Training Performance
# RMSE: 1562.1102522143615
# MAE: 791.3868517809933
# R2 score 115054.39455922165
# ...
